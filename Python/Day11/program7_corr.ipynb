# %% [markdown]
# ## read csv and find correlation between columns using df.corr()

# %%
# import the required packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /home/sakshi/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
# get the data
df=pd.read_csv("Salary_Data.csv")
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
#  Correlation , to see whether columns are related
df.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.983642
# Salary                  0.983642  1.000000

# %%
sns.pairplot(df)
plt.savefig('MyGraph.jpg')

# %%
df.corr().style.background_gradient(cmap="berlin")
# Out:
# <style type="text/css">
# #T_49494_row0_col0, #T_49494_row1_col1 {
#   background-color: #ffadad;
#   color: #000000;
# }
# #T_49494_row0_col1, #T_49494_row1_col0 {
#   background-color: #9eb0ff;
#   color: #000000;
# }
# </style>
# <table id="T_49494">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49494_level0_col0" class="col_heading level0 col0" >YearsExperience</th>
#       <th id="T_49494_level0_col1" class="col_heading level0 col1" >Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49494_level0_row0" class="row_heading level0 row0" >YearsExperience</th>
#       <td id="T_49494_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_49494_row0_col1" class="data row0 col1" >0.983642</td>
#     </tr>
#     <tr>
#       <th id="T_49494_level0_row1" class="row_heading level0 row1" >Salary</th>
#       <td id="T_49494_row1_col0" class="data row1 col0" >0.983642</td>
# ...

# %%
df.corr().style.background_gradient(cmap="Spectral")
# Out:
# <style type="text/css">
# #T_15ae3_row0_col0, #T_15ae3_row1_col1 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_15ae3_row0_col1, #T_15ae3_row1_col0 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_15ae3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15ae3_level0_col0" class="col_heading level0 col0" >YearsExperience</th>
#       <th id="T_15ae3_level0_col1" class="col_heading level0 col1" >Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15ae3_level0_row0" class="row_heading level0 row0" >YearsExperience</th>
#       <td id="T_15ae3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_15ae3_row0_col1" class="data row0 col1" >0.983642</td>
#     </tr>
#     <tr>
#       <th id="T_15ae3_level0_row1" class="row_heading level0 row1" >Salary</th>
#       <td id="T_15ae3_row1_col0" class="data row1 col0" >0.983642</td>
# ...

# %%
df.corr().style.background_gradient(cmap="vanimo")
# Out:
# <style type="text/css">
# #T_8a9bd_row0_col0, #T_8a9bd_row1_col1 {
#   background-color: #befda5;
#   color: #000000;
# }
# #T_8a9bd_row0_col1, #T_8a9bd_row1_col0 {
#   background-color: #ffcdfd;
#   color: #000000;
# }
# </style>
# <table id="T_8a9bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a9bd_level0_col0" class="col_heading level0 col0" >YearsExperience</th>
#       <th id="T_8a9bd_level0_col1" class="col_heading level0 col1" >Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a9bd_level0_row0" class="row_heading level0 row0" >YearsExperience</th>
#       <td id="T_8a9bd_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8a9bd_row0_col1" class="data row0 col1" >0.983642</td>
#     </tr>
#     <tr>
#       <th id="T_8a9bd_level0_row1" class="row_heading level0 row1" >Salary</th>
#       <td id="T_8a9bd_row1_col0" class="data row1 col0" >0.983642</td>
# ...

# %%
df.corr().style.background_gradient(cmap="vanimo")
# Out:
# <style type="text/css">
# #T_ad7b6_row0_col0, #T_ad7b6_row1_col1 {
#   background-color: #befda5;
#   color: #000000;
# }
# #T_ad7b6_row0_col1, #T_ad7b6_row1_col0 {
#   background-color: #ffcdfd;
#   color: #000000;
# }
# </style>
# <table id="T_ad7b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad7b6_level0_col0" class="col_heading level0 col0" >YearsExperience</th>
#       <th id="T_ad7b6_level0_col1" class="col_heading level0 col1" >Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad7b6_level0_row0" class="row_heading level0 row0" >YearsExperience</th>
#       <td id="T_ad7b6_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ad7b6_row0_col1" class="data row0 col1" >0.983642</td>
#     </tr>
#     <tr>
#       <th id="T_ad7b6_level0_row1" class="row_heading level0 row1" >Salary</th>
#       <td id="T_ad7b6_row1_col0" class="data row1 col0" >0.983642</td>
# ...

# %%
df.corr().style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_cf2f2_row0_col0, #T_cf2f2_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cf2f2_row0_col1, #T_cf2f2_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cf2f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf2f2_level0_col0" class="col_heading level0 col0" >YearsExperience</th>
#       <th id="T_cf2f2_level0_col1" class="col_heading level0 col1" >Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf2f2_level0_row0" class="row_heading level0 row0" >YearsExperience</th>
#       <td id="T_cf2f2_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_cf2f2_row0_col1" class="data row0 col1" >0.983642</td>
#     </tr>
#     <tr>
#       <th id="T_cf2f2_level0_row1" class="row_heading level0 row1" >Salary</th>
#       <td id="T_cf2f2_row1_col0" class="data row1 col0" >0.983642</td>
# ...
