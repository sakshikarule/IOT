# %%
print("Hello world")
# Out:
# Hello world

# %%
num = 100
print(num)
# Out:
# 100

# %%
print(f"num = {num}")
# f string is the formatted string literal
# anything { } is evaluated as python code
# Out:
# num = 100

# %%
a = 10
b = 20
print(a+b)
# Out:
# 30

# %%
# command shortcuts-
# esc + a : add a cell above the current cell
# esc + b : add a cell below the current cell
# enter : set the focus to the current cell
# esc + dd : delete the current cell
# esc + m : convert the type of cell to markdown
# esc + y : convert the type of cell to code
# shift + enter : executes the current cell and add a cell below it
# tab : shows intelliscence
